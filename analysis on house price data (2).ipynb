# %% [markdown]
# # Analysis on House Price Data

# %%
#  import numpy
import numpy as np

# import pandas 
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
# import the dataset
df_house_price_data = pd.read_csv("C:\\Users\\ADMIN\\Desktop\\House_Price.csv")

# %%
# show first 5 observations of the dataset
df_house_price_data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
# show last 5 observations of the dataset
df_house_price_data.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %% [markdown]
# # 1 Data Overview

# %%
# show the column(Attributes) names 
df_house_price_data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %% [markdown]
# **columninfo**
#  - `price`  : price of the house.
#  - `crime_rate`  : crime rate in that area
#  - `resid_area`  : residential of that area
#  - `air_qual`  : air quality of that area
#  - `room_num`  : residential of that area
#  - `age`  : How old that house is
#  - `dist1`  : distance of area from house for employment 1
#  - `dist2`  : distance of area from house for employment 2
#  - `dist3`  : distance of area from house for employment 3
#  - `dist4`  : distance of area from house for employment 4
#  - `teachers`  : Numbers of schools near residence
#  - `poor_prop`  : Poor population rate near the residental area
#  - `airport`  : any airport near the residence
#  - `n_hos_beds`  : hospital beds numbers
#  - `n_hot_rooms`  : Number of hotel rooms
#  - `waterbody`  : source of water near residence
#  - `rainfall`  : reainfall rate in that area
#  - `bus_ter`  : bus terminal near the residence
#  - `parks`  : Any park near the residence

# %% [markdown]
# ## Basic statistics ( Descriptive statistics)

# %%
# shape of the data
# basic info
# basic description

# %%
# shape of the data
df_house_price_data.shape
# Out:
# (506, 19)

# %% [markdown]
# **interpretation**
#  - We have 506 observation and 19 attributes

# %%
# basic info
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# **interpretation**
#  - We have 16 numerical attributes it includes 15 floats and 1 integer in nature.
#  - We have 3 categorical attributes
#  - In the data we have valid null values

# %%
# basic description
df_house_price_data.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   3.613524   8.601545   0.006320   0.082045   0.256510
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# ...

# %% [markdown]
# **interpretation**
#  - We have outliers is `crime_rate`,`resid_area`,`age`

# %% [markdown]
# # 2 Data Preprocessing

# %%
# Data Cleaning
# Null Value Handling
# Outlier treatment

# %% [markdown]
# ### Data Cleaning

# %%
df_house_price_data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %%
# let's rename the columns 
df_house_price_data = df_house_price_data.rename(columns={'price':'Price', 'crime_rate':'Crime_rate','resid_area':'Resid_area','air_qual':'Air_qual','room_num':'Room_num','age':'Age',
                                    'dist1':'Dist1', 'dist2':'Dist2', 'dist3':'Dist3', 'dist4':'Dist4', 'teachers':'Teachers', 'poor_prop':'Poor_prop', 'airport':'Airport',
                                    'n_hos_beds':'N_hos_beds', 'n_hot_rooms':'N_hot_rooms', 'waterbody':'Waterbody', 'rainfall':'Rainfall', 'bus_ter':'Bus_ter',
                                    'parks':'Parks'})

# %%
df_house_price_data.head()
# Out:
#    Price  Crime_rate  Resid_area  Air_qual  Room_num   Age  Dist1  Dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    Dist3  Dist4  Teachers  Poor_prop Airport  N_hos_beds  N_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   Waterbody  Rainfall Bus_ter     Parks
# 0     River        23     YES  0.049347
# ...

# %%
# let's do the Typecasting here
# Room_num
# Age
# Teachers
# N_hos_beds
# N_hot_rooms

# %%
df_house_price_data['Room_num'] = df_house_price_data['Room_num'].astype('int')

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        506 non-null    float64
#  1   Crime_rate   506 non-null    float64
#  2   Resid_area   506 non-null    float64
#  3   Air_qual     506 non-null    float64
#  4   Room_num     506 non-null    int32
#  5   Age          506 non-null    float64
#  6   Dist1        506 non-null    float64
#  7   Dist2        506 non-null    float64
#  8   Dist3        506 non-null    float64
#  9   Dist4        506 non-null    float64
#  10  Teachers     506 non-null    float64
#  11  Poor_prop    506 non-null    float64
#  12  Airport      506 non-null    object
#  13  N_hos_beds   498 non-null    float64
#  14  N_hot_rooms  506 non-null    float64
#  15  Waterbody    506 non-null    object
#  16  Rainfall     506 non-null    int64
#  17  Bus_ter      506 non-null    object
# ...

# %%
df_house_price_data['Age'] = df_house_price_data['Age'].astype('int')

# %%
df_house_price_data['Teachers'] = df_house_price_data['Teachers'].astype('int')

# %% [raw]
# df_house_price_data['N_hos_beds'] = df_house_price_data['N_hos_beds'].astype('int')

# %%
df_house_price_data['N_hot_rooms'] = df_house_price_data['N_hot_rooms'].astype('int')

# %%
# in previous we did the typecasting based on observation and domain expertuise
# Now the time is called Data visulization
df_house_price_data.hist()
plt.tight_layout()
plt.show()

# %%
df_house_price_data.Price.plot(kind = 'kde')
plt.show()

# %%
# Room_num

df_house_price_data.Room_num.hist(color = 'purple' )
plt.show()

# %%
# N_hot_rooms

df_house_price_data.N_hot_rooms.hist(color = 'red' )
plt.show()

# %%
df_house_price_data.N_hot_rooms.plot(kind = 'kde')
plt.show()

# %%
df_house_price_data['Room_num'] = df_house_price_data['Room_num'].astype('object')
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        506 non-null    float64
#  1   Crime_rate   506 non-null    float64
#  2   Resid_area   506 non-null    float64
#  3   Air_qual     506 non-null    float64
#  4   Room_num     506 non-null    object
#  5   Age          506 non-null    int32
#  6   Dist1        506 non-null    float64
#  7   Dist2        506 non-null    float64
#  8   Dist3        506 non-null    float64
#  9   Dist4        506 non-null    float64
#  10  Teachers     506 non-null    int32
#  11  Poor_prop    506 non-null    float64
#  12  Airport      506 non-null    object
#  13  N_hos_beds   498 non-null    float64
#  14  N_hot_rooms  506 non-null    int32
#  15  Waterbody    506 non-null    object
#  16  Rainfall     506 non-null    int64
#  17  Bus_ter      506 non-null    object
# ...

# %% [markdown]
# ### Null value handling

# %%
df_house_price_data.head()
# Out:
#    Price  Crime_rate  Resid_area  Air_qual Room_num  Age  Dist1  Dist2  Dist3  \
# 0   24.0     0.00632       32.31     0.538        6   65   4.35   3.81   4.18
# 1   21.6     0.02731       37.07     0.469        6   78   4.99   4.70   5.12
# 2   34.7     0.02729       37.07     0.469        7   61   5.03   4.86   5.01
# 3   33.4     0.03237       32.18     0.458        6   45   6.21   5.93   6.16
# 4   36.2     0.06905       32.18     0.458        7   54   6.16   5.86   6.37
#
#    Dist4  Teachers  Poor_prop Airport  N_hos_beds  N_hot_rooms Waterbody  \
# 0   4.01        24       4.98     YES       5.480           11     River
# 1   5.06        22       9.14      NO       7.332           12      Lake
# 2   4.97        22       4.03      NO       7.394          101      None
# 3   5.96        21       2.94     YES       9.268           11      Lake
# 4   5.86        21       5.33      NO       8.824           11      Lake
#
#    Rainfall Bus_ter     Parks
# ...

# %%
# find the number of missing values
df_house_price_data.isnull().sum()
# Out:
# Price          0
# Crime_rate     0
# Resid_area     0
# Air_qual       0
# Room_num       0
# Age            0
# Dist1          0
# Dist2          0
# Dist3          0
# Dist4          0
# Teachers       0
# Poor_prop      0
# Airport        0
# N_hos_beds     8
# N_hot_rooms    0
# Waterbody      0
# Rainfall       0
# Bus_ter        0
# Parks          0
# dtype: int64

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        506 non-null    float64
#  1   Crime_rate   506 non-null    float64
#  2   Resid_area   506 non-null    float64
#  3   Air_qual     506 non-null    float64
#  4   Room_num     506 non-null    object
#  5   Age          506 non-null    int32
#  6   Dist1        506 non-null    float64
#  7   Dist2        506 non-null    float64
#  8   Dist3        506 non-null    float64
#  9   Dist4        506 non-null    float64
#  10  Teachers     506 non-null    int32
#  11  Poor_prop    506 non-null    float64
#  12  Airport      506 non-null    object
#  13  N_hos_beds   498 non-null    float64
#  14  N_hot_rooms  506 non-null    int32
#  15  Waterbody    506 non-null    object
#  16  Rainfall     506 non-null    int64
#  17  Bus_ter      506 non-null    object
# ...

# %%
# lows 
# When we have less than 10% data is missing, remove the observation
# When we have missing % values 30 to 70% missing values than we need to inpute the missing values
# When we have more than 80% data is missing , remove the attributes

# %%
round(df_house_price_data.isnull().sum()/len(df_house_price_data)*100,2)
# Out:
# Price          0.00
# Crime_rate     0.00
# Resid_area     0.00
# Air_qual       0.00
# Room_num       0.00
# Age            0.00
# Dist1          0.00
# Dist2          0.00
# Dist3          0.00
# Dist4          0.00
# Teachers       0.00
# Poor_prop      0.00
# Airport        0.00
# N_hos_beds     1.58
# N_hot_rooms    0.00
# Waterbody      0.00
# Rainfall       0.00
# Bus_ter        0.00
# Parks          0.00
# dtype: float64

# %%
# Inpute the missing values present in waterbody
# find the mode of column
    # df_house_price_data.waterbody.mod()

# Replace the null values present in waterbody with river
    # df_house_price_data.waterbody.fillna('river',inplace = True)

# %%
# We have less than 2%  data is missing froms n_hos_beds. let's remove the observcations
df_house_price_data.dropna(inplace = True)

# %%
df_house_price_data.isnull().sum()
# Out:
# Price          0
# Crime_rate     0
# Resid_area     0
# Air_qual       0
# Room_num       0
# Age            0
# Dist1          0
# Dist2          0
# Dist3          0
# Dist4          0
# Teachers       0
# Poor_prop      0
# Airport        0
# N_hos_beds     0
# N_hot_rooms    0
# Waterbody      0
# Rainfall       0
# Bus_ter        0
# Parks          0
# dtype: int64

# %% [markdown]
# ### Outlier detection and tratment

# %%
df_house_price_data.plot(kind = 'box')
plt.xticks(rotation = 90)
plt.title('Outlier Detection')
plt.show()

# %%
df_num = df_house_price_data.select_dtypes(np.number)

# %%
# outliers treatment with iqr
Q1 = df_num.quantile(0.25)
Q3 = df_num.quantile(0.75)
IQR = Q3 - Q1
df_num = df_num[(df_num >= Q1 - 1.05* IQR) & (df_num <= Q3 + 1.05* IQR)]

# %%
df_num = df_num.reset_index()

# %%
df_num.plot(kind = 'box')
plt.xticks(rotation = 90)
plt.show()

# %%
# concate the treated the dataframe with categorical dataframe
df_cat= df_house_price_data.select_dtypes('object')

# %%
df_cat = df_cat.reset_index()

# %%
print(df_num.shape)
print(df_cat.shape)
# Out:
# (498, 16)
# (498, 5)

# %%
# concate both
df_house_price_data = pd.concat((df_num,df_cat), axis = 1)
df_house_price_data.shape
# Out:
# (498, 21)

# %%
df_house_price_data.isnull().sum()
# Out:
# index           0
# Price          71
# Crime_rate     80
# Resid_area      0
# Air_qual       16
# Age             0
# Dist1          16
# Dist2          17
# Dist3          15
# Dist4          16
# Teachers       15
# Poor_prop      23
# N_hos_beds      0
# N_hot_rooms     2
# Rainfall        1
# Parks          15
# index           0
# Room_num        0
# Airport         0
# Waterbody       0
# Bus_ter         0
# dtype: int64

# %%
df_house_price_data.dropna(inplace = True)

# %%
df_house_price_data.isnull().sum()
# Out:
# index          0
# Price          0
# Crime_rate     0
# Resid_area     0
# Air_qual       0
# Age            0
# Dist1          0
# Dist2          0
# Dist3          0
# Dist4          0
# Teachers       0
# Poor_prop      0
# N_hos_beds     0
# N_hot_rooms    0
# Rainfall       0
# Parks          0
# index          0
# Room_num       0
# Airport        0
# Waterbody      0
# Bus_ter        0
# dtype: int64

# %% [markdown]
# # 3 EDA

# %%
# Univerite Analysis
# Binary Analysis
# Multiverite Analysis

# %% [markdown]
# ### Univerite Analysis

# %%
# let's segregate the numerical column and the categorical columns
df_num = df_house_price_data.select_dtypes(include= np.number)

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %%
# Categorical data frames
df_cat = df_house_price_data.select_dtypes(include = ['object'] )

# %%
df_cat.head()
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 5        6     YES      None     YES
# 6        6     YES     River     YES
# 7        6      NO      Lake     YES

# %% [markdown]
# #### Room Number

# %%
# find the count of each category present in that particular column
df_cat.Room_num.value_counts()
# Out:
# 6    203
# 5     99
# 7     12
# 4      2
# 8      1
# 3      1
# Name: Room_num, dtype: int64

# %%
# Visulize the count
df_cat.Room_num.value_counts().plot(kind = 'bar', color = "blue")
plt.show()

# %% [markdown]
# **interpretation**
#  - We have inbalance data in the Room_num column
#  - 6 is a category who is dominating most, its count is 266
#  - 3 is the category having least number of observation, its count is 2

# %% [markdown]
# #### Airport

# %%
# find the values counts for Airport column 
df_cat.Airport.value_counts()
# Out:
# YES    178
# NO     140
# Name: Airport, dtype: int64

# %%
df_cat.Airport.value_counts().plot(kind = 'bar', color = 'pink')
plt.show()

# %% [markdown]
# **interpretation**
#  - We have balance data in the Airport columns
#  - In the data there is 273 places where Airport is present and 225 places where Airport is not

# %%
df_cat.head(2)
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES

# %% [markdown]
# #### Waterbody

# %%
# find the count of each catagory in the column
df_cat.Waterbody.value_counts()
# Out:
# River             117
# None               94
# Lake               61
# Lake and River     46
# Name: Waterbody, dtype: int64

# %%
df_cat.Waterbody.value_counts().plot(kind = 'bar', color = 'skyblue')
plt.title('Count Of Waterbody')
plt.ylabel('Count')
plt.xlabel('Waterbodys')
plt.xticks(rotation = 45)
plt.grid()
plt.show()

# %% [markdown]
# **interpretation**
#  - Most of the places having River as waterbody, it's count is 178
#  - There is few places where lake and River are the waterbodys
#  - This data is inbalance

# %%
df_cat.head(2)
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES

# %% [markdown]
# #### Bus_Ter

# %%
# find the count of each catagory in the column
df_cat.Bus_ter.value_counts()
# Out:
# YES    318
# Name: Bus_ter, dtype: int64

# %%
df_cat.Bus_ter.value_counts().plot(kind = 'bar', color = 'green')
plt.title('Count Of Bus Terminal')
plt.ylabel('Count')
plt.xlabel('Bus Terminal')
plt.grid()
plt.show()

# %% [markdown]
# **interpretation**
#  - All the places we have cantain the bus terminal
#  - ACTION: remove the column from the data

# %%
# Drop the column
df_house_price_data.drop('Bus_ter', axis = 1, inplace = True)

# %%
df_house_price_data.shape
# Out:
# (318, 20)

# %%
df_house_price_data.shape[1]
# Out:
# 20

# %% [markdown]
# # Univariate Analysis on numerical data

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Price

# %%
# find the minimum values
df_num.Price.min()
# Out:
# 11.0

# %%
# find the maximum values
df_num.Price.max()
# Out:
# 33.2

# %%
# find the Average values
df_num.Price.mean()
# Out:
# 21.900000000000006

# %%
df_num.Price.plot(kind = 'kde' , color = 'black')
plt.title('kde plot on Price')
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is slighty normal distributd
#  - The houses we have their prices lies in 8 lac to 40 lacs
#  - The House we have the least prices 11 lakh
#  - The House we have the maximum prices 33 lakh
#  - The Average House with Average prices 21 lakh

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Crime_rate

# %%
# find the minimum values
df_num.Crime_rate.min()
# Out:
# 0.00632

# %%
# find the maximum values
df_num.Crime_rate.max()
# Out:
# 7.36711

# %%
# find the Average values
df_num.Crime_rate.mean()
# Out:
# 0.9269877044025162

# %%
df_num.Crime_rate.plot(kind = 'kde' , color = 'blue')
plt.title('kde plot on crime rate')
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is slighty normal distributd
#  - This lies in 0.1 to 0.2%
#  - We have the least crime rate 0.00632 %
#  - We have the maximum crime rate 88.9762 %
#  - We have the Average crime rate 3.5889 %

# %% [markdown]
# #### Resid_area

# %%
# find the minimum values
df_num.Resid_area.min()
# Out:
# 31.47

# %%
# find the maximum values
df_num.Resid_area.max()
# Out:
# 57.74

# %%
# find the average values
df_num.Resid_area.mean()
# Out:
# 40.1944339622642

# %%
df_num.Resid_area.plot(kind = 'kde' , color = 'black')
plt.title('kde plot on Resid_area')
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is multi distributd
#  - First model lies between 30 to 40 and second model lies between 47 to 55
#  - We have minimum values 30.46
#  - We have maximum values 57.74
#  - We have Average values 41.12

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Air_qual

# %%
# find the minimum values
df_num.Air_qual.min()
# Out:
# 0.389

# %%
# find the maximum values
df_num.Air_qual.max()
# Out:
# 0.77

# %%
# find the average values
df_num.Air_qual.mean()
# Out:
# 0.5211691823899378

# %%
df_num.Air_qual.plot(kind = 'kde' , color = 'red')
plt.title('kde plot on Air_qual')
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - This lies in 0.38 to 0.77%
#  - We have minimum values 0.385
#  - We have maximum values 0.77
#  - We have Average values 0.553

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Age

# %%
# find the minimum values
df_num.Age.min()
# Out:
# 2

# %%
# find the maximum values
df_num.Age.max()
# Out:
# 100

# %%
# find the average values
df_num.Age.mean()
# Out:
# 63.106918238993714

# %%
df_num.Age.plot(kind= 'kde', color = 'blue')
plt.title("kde of age")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is left distributd
#  - This lies in 0 to 125
#  - We have minimum values 2
#  - We have maximum values 100
#  - We have Average values 68.048

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Dist1

# %%
# find the minimum values
df_num.Dist1.min()
# Out:
# 1.63

# %%
# find the maximum values
df_num.Dist1.max()
# Out:
# 8.62

# %%
# find the average values
df_num.Dist1.mean()
# Out:
# 4.326477987421383

# %%
df_num.Dist1.plot(kind= 'kde', color = 'blue')
plt.title("kde of Dist1")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is normally distributd
#  - This lies in 1 to9
#  - We have minimum values 1.63
#  - We have maximum values 8.62
#  - We have Average values 4.326

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Dist2

# %%
# find the minimum values
df_num.Dist2.min()
# Out:
# 1.41

# %%
# find the maximum values
df_num.Dist2.max()
# Out:
# 8.18

# %%
# find the average values
df_num.Dist2.mean()
# Out:
# 3.9827987421383653

# %%
df_num.Dist2.plot(kind= 'kde', color = 'blue')
plt.title("kde of Dist2")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is normally distributd
#  - We have minimum values 0.92
#  - We have maximum values 11.93
#  - We have Average values 3.6419

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Dist3

# %%
# find the minimum values
df_num.Dist3.min()
# Out:
# 1.68

# %%
# find the maximum values
df_num.Dist3.max()
# Out:
# 8.54

# %%
# find the average values
df_num.Dist3.mean()
# Out:
# 4.318930817610061

# %%
df_num.Dist3.plot(kind= 'kde', color = 'blue')
plt.title("kde of Dist3")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 1.15
#  - We have maximum values 12.32
#  - We have Average values 3.97339

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Dist4

# %%
# find the minimum values
df_num.Dist4.min()
# Out:
# 1.18

# %%
# find the maximum values
df_num.Dist4.max()
# Out:
# 8.03

# %%
# find the average values
df_num.Dist4.mean()
# Out:
# 3.9690880503144643

# %%
df_num.Dist4.plot(kind= 'kde', color = 'blue')
plt.title("kde of Dist4")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 0.73
#  - We have maximum values 11.94
#  - We have Average values 3.63046

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Teachers

# %%
# find the minimum values
df_num.Teachers.min()
# Out:
# 18.0

# %%
# find the maximum values
df_num.Teachers.max()
# Out:
# 25.0

# %%
# find the maximum values
df_num.Teachers.mean()
# Out:
# 20.87735849056604

# %%
df_num.Teachers.plot(kind= 'kde', color = 'blue')
plt.title("kde of Teachers")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 18
#  - We have maximum values 27
#  - We have Average values 21.030

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Poor_prop

# %%
# find the minimum values
df_num.Poor_prop.min()
# Out:
# 2.98

# %%
# find the maximum values
df_num.Poor_prop.max()
# Out:
# 27.26

# %%
# find the average values
df_num.Poor_prop.mean()
# Out:
# 11.279591194968551

# %%
df_num.Poor_prop.plot(kind= 'kde', color = 'blue')
plt.title("kde of Poor_prop")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 1.73
#  - We have maximum values 37.97
#  - We have Average values 12.599

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### N_hos_beds

# %%
# find the minimum values
df_num.N_hos_beds.min()
# Out:
# 5.332

# %%
# find the maximum values
df_num.N_hos_beds.max()
# Out:
# 10.648

# %%
# find the average values
df_num.N_hos_beds.mean()
# Out:
# 7.931081761006292

# %%
df_num.N_hos_beds.plot(kind= 'kde', color = 'blue')
plt.title("kde of N_hos_beds")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 5.268
#  - We have maximum values 10.876
#  - We have Average values 7.89976

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### N_hot_rooms

# %%
# find the minimum values
df_num.N_hot_rooms.min()
# Out:
# 10.0

# %%
# find the maximum values
df_num.N_hot_rooms.max()
# Out:
# 15.0

# %%
# find the average values
df_num.N_hot_rooms.mean()
# Out:
# 12.4874213836478

# %%
df_num.N_hot_rooms.plot(kind= 'kde', color = 'blue')
plt.title("kde of N_hot_rooms")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 10
#  - We have maximum values 101
#  - We have Average values 12.86746

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Rainfall

# %%
# find the minimum values
df_num.Rainfall.min()
# Out:
# 20.0

# %%
# find the maximum values
df_num.Rainfall.max()
# Out:
# 60.0

# %%
# find the average values
df_num.Rainfall.mean()
# Out:
# 38.361635220125784

# %%
df_num.Rainfall.plot(kind= 'kde', color = 'blue')
plt.title("kde of Rainfall")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 20
#  - We have maximum values 60
#  - We have Average values 38.361

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index
# 0      0
# 1      1
# 5      5
# 6      6
# ...

# %% [markdown]
# #### Parks

# %%
# find the minimum values
df_num.Parks.min()
# Out:
# 0.034687927

# %%
# find the maximum values
df_num.Parks.max()
# Out:
# 0.076655095

# %%
# find the average values
df_num.Parks.mean()
# Out:
# 0.05169146745597483

# %%
df_num.Parks.plot(kind= 'kde', color = 'blue')
plt.title("kde of Parks")
plt.grid()
plt.show()

# %% [markdown]
# **Interpertation**
#  - This data is not normally distributd
#  - We have minimum values 0.0346
#  - We have maximum values 0.0766
#  - We have Average values 0.0516

# %% [markdown]
# ### Bivariate Analysis

# %%
# step 1: Do the bivariate ayalysis for numerical veriable
# find the corelation
df_num.corr()
# Out:
#                 index     Price  Crime_rate  Resid_area  Air_qual       Age  \
# index        1.000000 -0.027861    0.514386    0.291067  0.397356  0.040224
# Price       -0.027861  1.000000   -0.314293   -0.424567 -0.449456 -0.495783
# Crime_rate   0.514386 -0.314293    1.000000    0.536328  0.700760  0.363190
# Resid_area   0.291067 -0.424567    0.536328    1.000000  0.739413  0.534726
# Air_qual     0.397356 -0.449456    0.700760    0.739413  1.000000  0.677780
# Age          0.040224 -0.495783    0.363190    0.534726  0.677780  1.000000
# Dist1       -0.202590  0.256051   -0.411462   -0.652197 -0.751220 -0.665349
# Dist2       -0.207048  0.253079   -0.408643   -0.655249 -0.753842 -0.663609
# Dist3       -0.208665  0.254824   -0.414010   -0.656729 -0.755881 -0.665889
# Dist4       -0.190334  0.257898   -0.397392   -0.655194 -0.747684 -0.670177
# Teachers    -0.190047  0.485077   -0.364324   -0.419968 -0.491038 -0.348343
# ...

# %%
# Draw the heat map or corelation
sns.heatmap(df_num.corr(), annot = True)
sns.set(rc = {"figure.figsize":(15,20)})

# %%
# price-parks
# Dist4 - Dist2
# Parks - Air_qual
# Dist4 - Dist1
# Dist4 - Dist3

# %% [markdown]
# #### parks - Price

# %%
sns.scatterplot(x = 'Parks', y = 'Price', data = df_num)
plt.title("Correlation beteen Parks and Price ", fontsize=20)
plt.xlabel('Parks')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Interpertation**
#  - There is silghtly negative correlation
#  - We can say that if the Price of house is high then the Parks is lesser

# %% [markdown]
# #### Parks - Air_qual

# %%
sns.scatterplot(x = 'Air_qual', y = 'Parks', data = df_num)
plt.title("Correlation beteen Air_qual and Parks ", fontsize=20)
plt.xlabel('Air_qual')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpertation**
#  - There is silghtly positive correlation
#  - We can say that if the Air_qual of house is high then the Parks is higher

# %% [markdown]
# #### Dist4 - Dist1

# %%
sns.scatterplot(x = 'Dist4', y = 'Dist1', data = df_num)
plt.title("Correlation beteen Dist4 and Dist1", fontsize=20)
plt.xlabel('Dist4')
plt.ylabel('Dist1')
plt.show()

# %% [markdown]
# **Interpertation**
#  - There is linear correlation
#  - We can say that if the distenace of emplyoeement hub 4 and distenace of emplyoeement hub1 is equal

# %% [markdown]
# #### Dist4 - Dist2

# %%
sns.scatterplot(x = 'Dist4', y = 'Dist2', data = df_num)
plt.title("Correlation beteen Dist4 and Dist2", fontsize=20)
plt.xlabel('Dist4')
plt.ylabel('Dist2')
plt.show()

# %% [markdown]
# **Interpertation**
#  - There is linear correlation
#  - We can say that if the distenace of emplyoeement hub4 and distenace of emplyoeement hub2 is equal

# %% [markdown]
# #### Dist4 - Dist3

# %%
sns.scatterplot(x = 'Dist4', y = 'Dist3', data = df_num)
plt.title("Correlation beteen Dist4 and Dist3", fontsize=20)
plt.xlabel('Dist4')
plt.ylabel('Dist3')
plt.show()

# %% [markdown]
# **Interpertation**
#  - There is linear correlation
#  - We can say that if the distenace of emplyoeement hub4 and distenace of emplyoeement hub3 is equal

# %%
# Parks
# Price
# Air_qual

# %%
#df_cat.dropna(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_cat.dropna(inplace = True)
#
# NameError: name 'df_cat' is not defined

# %%
df_cat.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_cat.head()
#
# NameError: name 'df_cat' is not defined

# %%
x = 'Room_num'
y = 'Parks'
plt.bar(x, y,data = df_house_price_data)
sns.set(rc = {"figure.figsize":(1,5)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - Average number of parks is high then number of room are 4
#  - Average number of parks is leser then number of room are 7

# %%
sns.barplot(x = 'Airport', y = 'Parks', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(1,1)})
plt.xlabel('Airport')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %%
sns.barplot(x = 'Waterbody', y = 'Parks', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(15,15)})
plt.xlabel('Waterbody')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %%
df_cat.columns
# Out:
# Index(['Room_num', 'Airport', 'Waterbody', 'Bus_ter'], dtype='object')

# %%
sns.barplot(x = 'Room_num', y = 'Price', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(15,15)})
plt.xlabel('Room_num')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the number of room are 7 than the price is high
#  - When the number of room are 4 than the price is less

# %%
sns.barplot(x = 'Airport', y = 'Price', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(15,15)})
plt.xlabel('Airport')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %%
sns.barplot(x = 'Waterbody', y = 'Price', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(1,1)})
plt.xlabel('Waterbody')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %%
sns.barplot(x = 'Room_num', y = 'Air_qual', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(5,5)})
plt.xlabel('Room_num')
plt.ylabel('Air_qual')
plt.show()

# %% [markdown]
# **Interpertation**
# - when we have best air quality in the area that time average room number is 4 in the house
# - when we have bed air quality in the area that time average room number is84 in the house

# %%
sns.barplot(x = 'Airport', y = 'Air_qual', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(1,1)})
plt.xlabel('Airport')
plt.ylabel('Air_qual')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %%
sns.barplot(x = 'Waterbody', y = 'Air_qual', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(5,0.5)})
plt.xlabel('Waterbody')
plt.ylabel('Air_qual')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %% [markdown]
# # Multiveriate Analysis

# %%
# Add hut
# Cross tab
# Pivot table

# %%
# Peirs
# col1: Price, col2: Parks col3: Room_num
# col1: Price, col2: Air_qual col3: Room_num
# col1: Price, col2: Poor_prop col3: Room_num

# col1: Price, col2: Parks col3: Airport
# col1: Price, col2: Air_qual col3: Airport
# col1: Price, col2: Poor_prop col3: Airport

# col1: Price, col2: Parks col3: Waterbody
# col1: Price, col2: Air_qual col3: Waterbody
# col1: Price, col2: Poor_prop col3: Waterbody

# Note: My column 3 should be hue parameter

# %%
df_house_price_data.columns
# Out:
# Index(['index', 'Price', 'Crime_rate', 'Resid_area', 'Air_qual', 'Age',
#        'Dist1', 'Dist2', 'Dist3', 'Dist4', 'Teachers', 'Poor_prop',
#        'N_hos_beds', 'N_hot_rooms', 'Rainfall', 'Parks', 'index', 'Room_num',
#        'Airport', 'Waterbody'],
#       dtype='object')

# %% [markdown]
# #### col1: Price, col2: Parks col3: Room_num

# %%
# scatter plot
sns.scatterplot(x='Price', y='Parks', hue='Room_num', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When no of Parks is high (0.08) that time the Price is low (13 lacs) the average No of roomsin that senarlo is 3
#  - When no of Parks is low (0.04) that time the Price of the house is high (36 lacs) the average No of roomsin that senarlo is 8

# %% [markdown]
# #### col1: Price, col2: Air_qual col3: Room_num

# %%
# scatter plot
sns.scatterplot(x='Price', y='Air_qual', hue='Room_num', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the price of the house is low (13 lac) that time air quality is really good(0.9) the average No of roomsin that senarlo is 4
#  - Price When the price of the house is high (36 lac) that time air quality is really bad (0.45) the average No of roomsin that senarlo is 8

# %% [markdown]
# #### col1: Price, col2: Poor_prop col3: Room_num

# %%
# scatter plot
sns.scatterplot(x='Price', y='Poor_prop', hue='Room_num', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the price of the house is high (36 lac) that time propulation of poor people is 4 the average No of roomsin that senarlo is 8
#  - Price When the price of the house is low (7 lac) that time propulation of poor people is 30 the average No of roomsin that senarlo is 4

# %% [markdown]
# #### col1: Price, col2: Parks col3: Airport

# %%
# scatter plot
sns.scatterplot(x='Price', y='Parks', hue='Airport', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [raw]
# **Interpertation**
#  - When the price of the house is high (37 lac) that no of parks is (0.045) that time there is airport is not present
#  - When the price of the house is low (13 lac) that no of parks is (0.068) that time there is airport is present

# %% [markdown]
# #### col1: Price, col2: Air_qual col3: Airport

# %%
# scatter plot
sns.scatterplot(x='Price', y='Air_qual', hue='Airport', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the price of the house is low (12 lac) that time of the air quality is really good (0.69) that time there is airport is present
#  - When the price of the house is high (35 lac) that time of the air quality is really bed (0.41) that time there is airport is not present

# %% [markdown]
# #### col1: Price, col2: Poor_prop col3: Airport

# %%
# scatter plot
sns.scatterplot(x='Price', y='Poor_prop', hue='Airport', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the price of the house is high (37 lac) that time propulation of poor people is 4 that time there is airport is not present
#  - When the price of the house is low (12 lac) that time propulation of poor people is 24 that time there is airport is present

# %% [markdown]
# #### col1: Price, col2: Parks col3: Waterbody

# %%
# scatter plot
sns.scatterplot(x='Price', y='Parks', hue='Waterbody', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the price of the house is high (37 lac) that time no of parks is (0.045) that time they have river as Waterbody
#  - When the price of the house is low (12 lac) that time no of parks is (0.0698) that time they have river as Waterbody

# %% [markdown]
# #### col1: Price, col2: Air_qual col3: Waterbody

# %%
# scatter plot
sns.scatterplot(x='Price', y='Air_qual', hue='Waterbody', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the price of the house is high (35 lac) that time of the air quality is really bed (0.40) that time they have lake and river as Waterbody
#  - When the price of the house is low (12 lac) that time of the air quality is really good (0.69) that time they have river as Waterbody

# %% [markdown]
# #### col1: Price, col2: Poor_prop col3: Waterbody

# %%
# scatter plot
sns.scatterplot(x='Price', y='Poor_prop', hue='Waterbody', data = df_house_price_data)
sns.set(rc = {"figure.figsize":(10,10)})
plt.show()

# %% [markdown]
# **Interpertation**
#  - When the price of the house is high (35 lac) that time propulation of poor people is 4 that time they have lake as Waterbody
#  - When the price of the house is low (12 lac) that time propulation of poor people is 22 that time they have river as Waterbody

# %% [markdown]
# # Arrengement of pivot and ceoss tab

# %%
# col1: Room_num, co2: Airport, col3: Price
# col1: Room_num, co2: Waterbody, col3: Price
# col1: Airport, co2: Waterbody, col3: Price

# %%
df_house_price_data.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
# 7      7   22.1     0.14455       37.87     0.524   96   6.04   5.85   6.25
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0      23.0  0.049347
# 1   5.06      22.0       9.14       7.332         12.0      42.0  0.046146
# 5   5.99      21.0       5.21       7.174         14.0      53.0  0.045910
# 6   5.20      24.0      12.43       6.958         12.0      41.0  0.052170
# 7   5.66      24.0      19.15       5.842         12.0      56.0  0.057075
#
#    index Room_num Airport Waterbody
# ...

# %% [markdown]
# #### col1: Room_num, co2: Airport, col3: Price

# %%
df_house_price_data.columns
# Out:
# Index(['index', 'Price', 'Crime_rate', 'Resid_area', 'Air_qual', 'Age',
#        'Dist1', 'Dist2', 'Dist3', 'Dist4', 'Teachers', 'Poor_prop',
#        'N_hos_beds', 'N_hot_rooms', 'Rainfall', 'Parks', 'index', 'Room_num',
#        'Airport', 'Waterbody'],
#       dtype='object')

# %% [markdown]
# ### Cross Tab

# %%
pd.crosstab(df_house_price_data.Room_num, 
            df_house_price_data.Airport, 
            values = df_house_price_data.Price, 
            aggfunc = "mean")
# Out:
# Airport          NO        YES
# Room_num
# 3               NaN  27.500000
# 4         19.000000        NaN
# 5         18.630435  19.811321
# 6         22.928235  22.505085
# 7         29.916667  30.966667
# 8         21.900000        NaN

# %% [markdown]
# #### col1: Room_num, co2: Waterbody, col3: Price

# %%
pd.crosstab(df_house_price_data.Room_num, 
            df_house_price_data.Waterbody, 
            values = df_house_price_data.Price, 
            aggfunc = "mean")
# Out:
# Waterbody       Lake  Lake and River       None      River
# Room_num
# 3                NaN             NaN        NaN  27.500000
# 4          21.900000             NaN        NaN  16.100000
# 5          18.647826       19.814286  19.375000  19.358824
# 6          21.842424       22.287097  22.290476  23.532895
# 7          30.025000       32.200000  31.033333  29.975000
# 8                NaN             NaN        NaN  21.900000

# %% [markdown]
# #### col1: Airport, co2: Waterbody, col3: Price

# %%
pd.crosstab(df_house_price_data.Airport, 
            df_house_price_data.Waterbody, 
            values = df_house_price_data.Price, 
            aggfunc = "mean")
# Out:
# Waterbody       Lake  Lake and River       None      River
# Airport
# NO         20.608000       20.548000  22.289474  22.488462
# YES        21.569444       23.180952  21.301786  22.503077

# %%
pd.pivot_table( data = df_house_price_data, index= "Airport",
    columns="Waterbody",
    values="Price",
    aggfunc= 'mean',)
# Out:
# Waterbody       Lake  Lake and River       None      River
# Airport
# NO         20.608000       20.548000  22.289474  22.488462
# YES        21.569444       23.180952  21.301786  22.503077
